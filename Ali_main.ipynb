# %%
import pandas as pd
import json
import os
import matplotlib.pyplot as plt
import seaborn as sns
from pprint import pprint
import numpy as np

# %%
filepath = os.path.join(".", "Resources", "clean_crash_population.csv")
df = pd.read_csv(filepath, low_memory=False)

# %%
df
# Out:
#        Crash ID State  Crash Month  Year    Dayweek   Time Crash Type  \
# 0      20212045   Vic            6  2021     Monday   5:40     Single
# 1      20212082   Vic            6  2021     Sunday  14:00     Single
# 2      20212079   Vic            6  2021   Saturday  13:25     Single
# 3      20212111   Vic            6  2021   Thursday  16:50     Single
# 4      20212149   Vic            6  2021  Wednesday  14:38   Multiple
# ...         ...   ...          ...   ...        ...    ...        ...
# 40505  19894033    SA            1  1989     Friday  15:35     Single
# 40506  19894028    SA            1  1989   Thursday  10:00     Single
# 40507  19894151    SA            1  1989  Wednesday  11:45   Multiple
# 40508  19894095    SA            1  1989   Thursday  18:00   Multiple
# 40509  19894145    SA            1  1989   Saturday  19:20     Single
#
#       Bus Involvement Heavy Rigid Truck Involvement  \
# 0                  No                            No
# 1                  No                            No
# 2                  No                            No
# 3                  No                            No
# 4                  No                            No
# ...               ...                           ...
# 40505              No                           NaN
# 40506              No                           NaN
# 40507              No                           NaN
# 40508              No                           NaN
# 40509              No                           NaN
#
#       Articulated Truck Involvement  ... Christmas Period Easter Period  \
# 0                                No  ...               No            No
# 1                                No  ...               No            No
# 2                                No  ...               No            No
# 3                                No  ...               No            No
# 4                                No  ...               No            No
# ...                             ...  ...              ...           ...
# 40505                            No  ...               No            No
# 40506                            No  ...               No            No
# 40507                            No  ...               No            No
# 40508                            No  ...               No            No
# 40509                            No  ...               No            No
#
#       Age Group  Day of week Time of day Quarter Population Month     Male  \
# 0      26_to_39      Weekend       Night      Q2                6  3291572
# 1      40_to_64      Weekend         Day      Q2                6  3291572
# 2      65_to_74      Weekend         Day      Q2                6  3291572
# 3      40_to_64      Weekday         Day      Q2                6  3291572
# 4      17_to_25      Weekday         Day      Q2                6  3291572
# ...         ...          ...         ...     ...              ...      ...
# 40505   0_to_16      Weekday         Day      Q1                3   703474
# 40506  40_to_64      Weekday         Day      Q1                3   703474
# 40507  65_to_74      Weekday         Day      Q1                3   703474
# 40508  65_to_74      Weekday       Night      Q1                3   703474
# 40509  26_to_39      Weekend       Night      Q1                3   703474
#
#         Female      All
# 0      3357587  6649159
# 1      3357587  6649159
# 2      3357587  6649159
# 3      3357587  6649159
# 4      3357587  6649159
# ...        ...      ...
# 40505   713464  1416938
# 40506   713464  1416938
# 40507   713464  1416938
# 40508   713464  1416938
# 40509   713464  1416938
#
# [40510 rows x 28 columns]

# %%
filepath = os.path.join(".", "Resources", "Crash_Data.csv")
df = pd.read_csv(filepath, low_memory=False)

# %%
df
# Out:
#        Crash ID State  Month  Year    Dayweek   Time Crash Type  \
# 0      20212133   Vic      9  2021     Sunday   0:30     Single
# 1      20214022    SA      9  2021   Saturday  23:31   Multiple
# 2      20212096   Vic      9  2021   Saturday  23:00     Single
# 3      20212145   Vic      9  2021   Saturday  22:25     Single
# 4      20212075   Vic      9  2021   Saturday   5:15     Single
# ...         ...   ...    ...   ...        ...    ...        ...
# 52838  19891246   NSW      1  1989  Wednesday  17:05     Single
# 52839  19895088    WA      1  1989     Monday   6:00     Single
# 52840  19895088    WA      1  1989     Monday   6:00     Single
# 52841  19895088    WA      1  1989     Monday   6:00     Single
# 52842  19896063   Tas      1  1989    Tuesday  12:40   Multiple
#
#       Bus Involvement Heavy Rigid Truck Involvement  \
# 0                 NaN                           NaN
# 1                  No                            No
# 2                 NaN                           NaN
# 3                 NaN                           NaN
# 4                 NaN                           NaN
# ...               ...                           ...
# 52838             Yes                           NaN
# 52839              No                           NaN
# 52840              No                           NaN
# 52841              No                           NaN
# 52842              No                           NaN
#
#       Articulated Truck Involvement  ... Age  National Remoteness Areas  \
# 0                               NaN  ...  38   Inner Regional Australia
# 1                                No  ...  28  Major Cities of Australia
# 2                               NaN  ...  19   Inner Regional Australia
# 3                               NaN  ...  23   Outer Regional Australia
# 4                               NaN  ...  46  Major Cities of Australia
# ...                             ...  ...  ..                        ...
# 52838                            No  ...   5                        NaN
# 52839                            No  ...  19                        NaN
# 52840                            No  ...  17                        NaN
# 52841                            No  ...  17                        NaN
# 52842                            No  ...  63                        NaN
#
#                 SA4 Name 2016  National LGA Name 2017 National Road Type  \
# 0      Melbourne - Outer East        Yarra Ranges (S)      Arterial Road
# 1            Adelaide - North            Playford (C)                NaN
# 2                        Hume         Wangaratta (RC)        Access road
# 3                        Hume         Wangaratta (RC)      Arterial Road
# 4      Melbourne - South East               Casey (C)         Local Road
# ...                       ...                     ...                ...
# 52838                     NaN                     NaN                NaN
# 52839                     NaN                     NaN                NaN
# 52840                     NaN                     NaN                NaN
# 52841                     NaN                     NaN                NaN
# 52842                     NaN                     NaN                NaN
#
#       Christmas Period Easter Period Age Group Day of week Time of day
# 0                   No            No  26_to_39     Weekend       Night
# 1                   No            No  26_to_39     Weekend       Night
# 2                   No            No  17_to_25     Weekend       Night
# 3                   No            No  17_to_25     Weekend       Night
# 4                   No            No  40_to_64     Weekend       Night
# ...                ...           ...       ...         ...         ...
# 52838               No            No   0_to_16     Weekday         Day
# 52839              Yes            No  17_to_25     Weekday         Day
# 52840              Yes            No  17_to_25     Weekday         Day
# 52841              Yes            No  17_to_25     Weekday         Day
# 52842               No            No  40_to_64     Weekday         Day
#
# [52843 rows x 23 columns]
